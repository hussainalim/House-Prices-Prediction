# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/housing.csv'

# %%
from google.colab import files
files.download(file_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
# Drop the 'median_house_value' column from the DataFrame (data) to create the feature set (X)
# The 'axis=1' parameter indicates that we are dropping a column (not a row)
x = data.drop(['median_house_value'], axis=1)

# Extract the 'median_house_value' column as the target variable (y)
y = data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2 , random_state = 42)

# %%
train_data = x_train.join(y_train)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
print(train_data.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# ocean_proximity        object
# median_house_value    float64
# dtype: object

# %%
# Apply one-hot encoding to the 'ocean_proximity' column in the data DataFrame
# pd.get_dummies creates dummy variables for categorical features
# The 'drop_first=True' parameter drops the first category to avoid multicollinearity (reducing one dummy column)
data = pd.get_dummies(data, columns=['ocean_proximity'], drop_first=True)

# %%
# Set the size of the plot to 15 inches by 8 inches
plt.figure(figsize=(15,8))

# Create a heatmap to visualize the correlation matrix of the 'data' DataFrame
# data.corr() calculates the correlation between numerical columns in the DataFrame
# annot=True adds the correlation values as annotations on the heatmap cells
# cmap="YlGnBu" sets the color map to a blue-green color scheme for better visibility
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
print(train_data.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# ocean_proximity        object
# median_house_value    float64
# dtype: object

# %%
# Apply logarithmic transformation to the specified columns in the data DataFrame
# The transformation is applied to 'total_rooms', 'total_bedrooms', 'population', and 'households' with a log(1+x) function
# The +1 inside the log function ensures that there are no issues with taking the log of zero (log(0) is undefined)
data['total_rooms'] = np.log(data['total_rooms'] + 1)
data['total_bedrooms'] = np.log(data['total_bedrooms'] + 1)
data['population'] = np.log(data['population'] + 1)
data['households'] = np.log(data['households'] + 1)

# %%
data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0     6.781058        4.867534
# 1        -122.22     37.86                21.0     8.867850        7.009409
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 3        -122.25     37.85                52.0     7.150701        5.463832
# 4        -122.25     37.85                52.0     7.395108        5.638355
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0     7.418181        5.926926
# 20636    -121.21     39.49                18.0     6.548219        5.017280
# 20637    -121.22     39.43                17.0     7.720905        6.186209
# 20638    -121.32     39.43                18.0     7.528869        6.016157
# 20639    -121.24     39.37                16.0     7.932362        6.424869
#
# ...

# %%
# Set the size of the plot to 15 inches by 8 inches
plt.figure(figsize=(15,8))

# Create a scatter plot to visualize the relationship between 'latitude' and 'longitude'
# The 'hue' parameter colors the points based on the 'median_house_value', using the 'coolwarm' color palette
sns.scatterplot(x='latitude', y='longitude', data=data, hue='median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# Create a new column 'bedrooms_ratio' by dividing 'total_bedrooms' by 'total_rooms'
# This ratio indicates the proportion of bedrooms in a house relative to the total number of rooms
data['bedrooms_ratio'] = data['total_bedrooms'] / data['total_rooms']

# Create a new column 'households_rooms' by dividing 'households' by 'total_rooms'
# This ratio indicates the number of households per room, which can help assess housing density
data['households_rooms'] = data['households'] / data['total_rooms']

# %%
# Set the size of the plot to 15 inches by 8 inches for better visibility
plt.figure(figsize=(15,8))

# Create a heatmap to visualize the correlation matrix of the 'data' DataFrame
# data.corr() calculates the correlation between numerical columns in the DataFrame
# annot=True adds the correlation values as annotations in each cell of the heatmap
# cmap="YlGnBu" applies a blue-green color palette to represent the correlation values visually
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# Define the feature set (x_train) by dropping the 'median_house_value' column from the data DataFrame
# This is done to separate the independent variables (features) from the target variable
x_train = data.drop(['median_house_value'], axis=1)

# Define the target variable (y_train) by selecting the 'median_house_value' column
# This represents the dependent variable we want to predict
y_train = data['median_house_value']

# Initialize the LinearRegression model
# LinearRegression is used to fit a linear relationship between the features and the target variable
reg = LinearRegression()

# Fit the LinearRegression model on the training data (x_train and y_train)
# This step trains the model to learn the relationship between the features and the target variable
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Combine the x_test and y_test datasets into one DataFrame for easier manipulation
# This merges the features (x_test) with the target variable (y_test)
test_data = x_test.join(y_test)

# Apply log transformation to specified columns to handle skewness (adding 1 to avoid log(0) errors)
# The log transformation helps normalize the data and makes the model more effective
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# One-hot encode the 'ocean_proximity' column (commented out here for potential later use)
# The following line would create dummy variables for 'ocean_proximity' and drop the original column
# test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity'], drop_first=True)).drop(['ocean_proximity'], axis=1)

# Calculate new features based on existing columns:
# 'bedroom_ratio' gives the proportion of bedrooms to total rooms, helping to assess space usage
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']

# 'household_rooms' gives the ratio of total rooms to households, potentially indicating room availability per household
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# Separate the features (x_test) and the target variable (y_test) for testing
# x_test now contains the transformed features, and y_test is the target variable
x_test = test_data.drop(['median_house_value'], axis=1)
y_test = test_data['median_house_value']

# %%
# Assuming x_train and y_train have already been prepared and the model has been trained

# Define x_test by dropping the 'median_house_value' column (target variable) from the data DataFrame
# This creates the feature set for testing, which should have the same structure as x_train
x_test = data.drop(['median_house_value'], axis=1)

# Define y_test by selecting the 'median_house_value' column as the target variable for testing
y_test = data['median_house_value']

# Align x_test columns with x_train by reordering the columns of x_test to match the order of x_train
# This ensures that the feature columns in x_test are in the same order as in x_train
# The fill_value=0 ensures that any missing columns in x_test are filled with 0s
x_test = x_test.reindex(columns=x_train.columns, fill_value=0)

# Now evaluate the trained model by using the score method
# The reg.score() method returns the R^2 (coefficient of determination) of the prediction
# It measures how well the model explains the variance in the target variable (y_test)
reg.score(x_test, y_test)
# Out:
# 0.6711261847150751

# %% [markdown]
# # **Quick important note** : You can get better performance using another algorithm like desicion trees

# %%
# Import RandomForestRegressor from sklearn.ensemble for regression tasks using random forests
from sklearn.ensemble import RandomForestRegressor

# Initialize the RandomForestRegressor model
# RandomForestRegressor is an ensemble learning method that combines multiple decision trees to improve accuracy
forest = RandomForestRegressor()

# Fit the RandomForestRegressor model on the training data (x_train and y_train)
# This step trains the model to learn the relationship between the features (x_train) and the target variable (y_train)
forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Evaluate the performance of the trained RandomForestRegressor model using the score method
# The forest.score() method returns the R^2 (coefficient of determination) of the prediction
# It measures how well the model explains the variance in the target variable (y_test)
forest.score(x_test, y_test)
# Out:
# 0.9752953329570234
